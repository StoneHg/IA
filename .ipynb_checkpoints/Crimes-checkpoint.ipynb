# %% [markdown]
# E aí pessoal, beleza? Como vai a quarentena?
# A Prefs de São Paulo(cópia barata da Prefs de Curitiba, a original) pediu pra nós da GoTask analisarmos dados de crimes em São Paulo no ano de 2016, pra levantar dados para comparar um ano com o outro e remanejar melhor os policiais e vamos mostrar o passo a passo pra vocês, porque somos legais, não vamos receber nota por isso... >:D
# A planilha é bem grande, galera! São 50 mil dados que levam em consideração o local, o tipo de crime e onde foram registrados, etc, etc, etc...

# %% [markdown]
# Nós vamos usar o Pandas, porque é fofinho, bonitinho e dá vontade de abraçar? NÃÃÃO! Mas porque vai ajudar a gente a trabalhar com esses dados de planilha, organizando e selecionando. Então #partiu.

# %% [markdown]
# Importamos o pandas e criamos a variável pd pra ele.

# %%
import pandas as pd

# %% [markdown]
# Como o arquivo que recebemos é do excel em formato csv, criamos a variável data pra salvar esse dado e exibir ele aqui e pedimos pro pandas "ei fofinho, pode ler esse arquivo csv pra gente?" E se ele gostar de você, vai rodar, tente a sorte. PS: Protesto da única mulher do grupo! Deveria ser pra pandas, porque é umA bibliotecA.

# %%
data = pd.read_csv('crimes_2016.csv')

# %%
data
# Out:
#         NUM_BO  ANO_BO  ID_DELEGACIA  \
# 0        10957    2016         20249
# 1         1672    2016         20230
# 2          211    2016         10376
# 3         4438    2016         10323
# 4       676155    2016        900020
# ...        ...     ...           ...
# 49995     2063    2016         10374
# 49996  1356710    2016        900020
# 49997     1318    2016         10359
# 49998     5536    2016         10336
# 49999     1238    2016         20301
#
#                               NOME_DEPARTAMENTO  \
# 0      DECAP
# 1      DECAP
# 2      DECAP
# 3      DECAP
# 4      DIPOL - DEPTO DE INTELIGENCIA
# ...                                         ...
# 49995  DECAP
# 49996  DIPOL - DEPTO DE INTELIGENCIA
# 49997  DECAP
# 49998  DECAP
# 49999  DECAP
#
#                                  NOME_SECCIONAL  \
# 0      DEL.SEC.8º SAO MATEUS
# 1      DEL.SEC.5º LESTE
# 2      DEL.SEC.3º OESTE
# 3      DEL.SEC.3º OESTE
# 4      DELEGACIA ELETRONICA
# ...

# %% [markdown]
# VOILÁ! Temos a boa e a má notícia, vamos começar pela boa: Ele gosta de você, parabéns. A má notícia... Não tem má notícia, 50 mil linhas tá ótimo, hashtag #amamos. Poderíamos ter usado o .head() pra trazer as primeiras linhas pra ver se tá tudo funcionando? Sim, poderíamos.

# %% [markdown]
# ...

# %% [markdown]
# ...

# %% [markdown]
# ...

# %% [markdown]
# TÁ BÃO!

# %%
data.head()
# Out:
#    NUM_BO  ANO_BO  ID_DELEGACIA                         NOME_DEPARTAMENTO  \
# 0   10957    2016         20249  DECAP
# 1    1672    2016         20230  DECAP
# 2     211    2016         10376  DECAP
# 3    4438    2016         10323  DECAP
# 4  676155    2016        900020  DIPOL - DEPTO DE INTELIGENCIA
#
#                              NOME_SECCIONAL                       DELEGACIA  \
# 0  DEL.SEC.8º SAO MATEUS                     49º D.P.  SAO MATEUS
# 1  DEL.SEC.5º LESTE                          30º D.P.  TATUAPE
# 2  DEL.SEC.3º OESTE                          09ª DEL.DEF.MUL. OESTE
# 3  DEL.SEC.3º OESTE                          23º D.P.  PERDIZES
# 4  DELEGACIA ELETRONICA                      DELEGACIA ELETRONICA
#
#                      NOME_DEPARTAMENTO_CIRC  \
# 0  DECAP
# 1  DECAP
# 2  DECAP
# 3  DECAP
# 4  DECAP
#
#                         NOME_SECCIONAL_CIRC             NOME_DELEGACIA_CIRC  \
# 0  DEL.SEC.8º SAO MATEUS                     49º D.P.  SAO MATEUS
# ...

# %% [markdown]
# Pronto, pronto... #diferentoes

# %% [markdown]
# Beleza, agora vamos ver quantas cidades tem nesse arquivo? Vamos usar o .value_counts(), que vai retornar os valores únicos pra gente, nesse caso a gente quer ver só as cidades mesmo. Então pegamos nosso arquivo e selecionamos o campo CIDADE, assim ó:

# %%
data['CIDADE'].value_counts()
# Out:
# S.PAULO                                     33168
# GUARULHOS                                    2255
# S.BERNARDO DO CAMPO                          1811
# S.ANDRE                                      1799
# OSASCO                                       1736
# DIADEMA                                      1120
# MAUA                                          871
# CARAPICUIBA                                   704
# MOGI DAS CRUZES                               615
# ITAQUAQUECETUBA                               557
# SUZANO                                        472
# BARUERI                                       466
# TABOAO DA SERRA                               436
# COTIA                                         397
# FERRAZ DE VASCONCELOS                         305
# ITAPECERICA DA SERRA                          295
# ITAPEVI                                       292
# EMBU                                          291
# S.CAETANO DO SUL                              275
# ...

# %% [markdown]
# Ora ora... mais de 33 mil resultados, São Paulo? Eita preula. Era você mesmo que queríamos!

# %% [markdown]
# Beleza, já sabemos que 'S.PAULO' aparece mais de 33 mil vezes, então agora vamos pegar todas as colunas e só as linhas que correspondem a São Paulo, assim ó:

# %%
dataCidade = data.loc[data.CIDADE == "S.PAULO", :]

# %% [markdown]
# Vamo vê no que deu...

# %%
dataCidade
# Out:
# Empty DataFrame
# Columns: [NUM_BO, ANO_BO, ID_DELEGACIA, NOME_DEPARTAMENTO, NOME_SECCIONAL, DELEGACIA, NOME_DEPARTAMENTO_CIRC, NOME_SECCIONAL_CIRC, NOME_DELEGACIA_CIRC, ANO, MES, FLAG_STATUS, RUBRICA, DESDOBRAMENTO, CONDUTA, LATITUDE, LONGITUDE, CIDADE, LOGRADOURO, NUMERO_LOGRADOURO, FLAG_STATUS.1]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# AI MEU DEUS! QUEDELE?

# %% [markdown]
# É... s*** happens. Nosso arquivo tem um pequeno detalhe, ele tem excessos de carácteres sabe-deus-o-que, tipo espaços e etc. Então acontece isso :( #chateado

# %% [markdown]
# Maaas, nem tudo é choro. Vamos tentar resolver essa parada aí.

# %% [markdown]
# Vamos começar tudo de novo. Sim, errar é 1mano.

# %% [markdown]
# WE CAN DO IT! Vamos usar o ThGex(Regex da Thais) pra eliminar o excesso de espaços.

# %%
data = pd.read_csv("crimes_2016.csv", sep="\s*,\s*")
# Out:
# C:\Users\leticia.bora\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-63-2dccd7c57b62> in <module>
# ----> 1 data = pd.read_csv("crimes_2016.csv", sep="\s*,\s*")
#
# ...

# %% [markdown]
# Ai que querido, né? Mas como diria Chapolin: "Palma, palma, palma! Não priemos cânico!"

# %% [markdown]
# Tem mágica pra resolver isso? Não. Deve ter uma abordagem melhor? Sim. Mas é o que temos pra hoje, então vamos lá:

# %%
data = pd.read_csv("crimes_2016.csv", sep="\s*,\s*", error_bad_lines=False)
# Out:
# C:\Users\leticia.bora\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# Skipping line 22: Expected 21 fields in line 22, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 34: Expected 21 fields in line 34, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 37: Expected 21 fields in line 37, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 50: Expected 21 fields in line 50, saw 22. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# ...

# %% [markdown]
# TÁ POR**!

# %% [markdown]
# Mas que coisa é essa de error_bad_lines=False?? #ajudaLuciano

# %% [markdown]
# Então, error_bad_lines="False" vai pegar todas as linhas que não se deram muito bem com a gente, que não concordam com o ThGex que tenham só espaços e coisas assim e vai falar assim: "Vem cá, bebês, venham aqui no cantinho conversar com o tio". Ou seja, vai pegar todas essas linhas e ignorá-las...

# %% [markdown]
# Não chora!

# %% [markdown]
# Ei, princesa! Ergue a cabeça, senão a coroa cai!

# %% [markdown]
# Tá doendo, né? Você gostava delas, nós também...

# %% [markdown]
# *warn_bad_lines entrou no grupo*
#
# *engine=python mostrou pro C quem é que manda*

# %% [markdown]
# **warn_bad_lines diz:** O que os olhos não vêem o coração não sente.

# %%
data = pd.read_csv("crimes_2016.csv", sep="\s*,\s*", engine="python", error_bad_lines=False, warn_bad_lines=False)

# %%
data
# Out:
#         NUM_BO  ANO_BO  ID_DELEGACIA              NOME_DEPARTAMENTO  \
# 0        10957    2016         20249                          DECAP
# 1         1672    2016         20230                          DECAP
# 2          211    2016         10376                          DECAP
# 3         4438    2016         10323                          DECAP
# 4       676155    2016        900020  DIPOL - DEPTO DE INTELIGENCIA
# ...        ...     ...           ...                            ...
# 44736     2063    2016         10374                          DECAP
# 44737  1356710    2016        900020  DIPOL - DEPTO DE INTELIGENCIA
# 44738     1318    2016         10359                          DECAP
# 44739     5536    2016         10336                          DECAP
# 44740     1238    2016         20301                          DECAP
#
#                 NOME_SECCIONAL                  DELEGACIA  \
# 0       DEL.SEC.8Âº SAO MATEUS      49Âº D.P.  SAO MATEUS
# ...

# %% [markdown]
# XABLAAAAU! Ok, ok. Perdemos um pouco mais de 5 mil resultados aqui, mas... O que tá acontencendo? Que mensagem é essa caindo do céu as 22:31 de uma sexta-feira 17/04/2020? Será uma mensagem do além? Vamos ler o que a mensagem nos diz:

# %% [markdown]
# *eita*
#
# *haha* (pessoa ri da desgraça alheia)
#
# *tudo bem*
#
# *só deixa explicadinho isso pra mim, mas pode seguir com o 44 mil*

# %% [markdown]
# Ufa Nayara, quase tivemo um infarto do coração
#
# ps: Pra quem não tem o contexto desse ícone maravilhoso: https://www.youtube.com/watch?v=O8ebPb4UyFc

# %% [markdown]
# Vamos recaptular, já que dos 5 integrantes do grupo, 6 tem TDA.

# %% [markdown]
# Então, usamos o .loc pra dizer assim "Olhe esses dados, na minha época era tudo mato! Veja só a coluna CIDADE, como cresceu essa bendita... Ela tem trocentas cidades dentro dela... Mas eu só queria saber o que aconteceu dentro da cidade de São Paulo (S.PAULO), me mostre tudo, todos os dados de todas as outras colunas que se referem a Sampa".

# %%
dataCidade = data.loc[data.CIDADE == "S.PAULO", :]

# %%
dataCidade
# Out:
#         NUM_BO  ANO_BO  ID_DELEGACIA              NOME_DEPARTAMENTO  \
# 0        10957    2016         20249                          DECAP
# 1         1672    2016         20230                          DECAP
# 2          211    2016         10376                          DECAP
# 3         4438    2016         10323                          DECAP
# 4       676155    2016        900020  DIPOL - DEPTO DE INTELIGENCIA
# ...        ...     ...           ...                            ...
# 44736     2063    2016         10374                          DECAP
# 44737  1356710    2016        900020  DIPOL - DEPTO DE INTELIGENCIA
# 44738     1318    2016         10359                          DECAP
# 44739     5536    2016         10336                          DECAP
# 44740     1238    2016         20301                          DECAP
#
#                 NOME_SECCIONAL                  DELEGACIA  \
# 0       DEL.SEC.8Âº SAO MATEUS      49Âº D.P.  SAO MATEUS
# ...

# %% [markdown]
# TCHARAAAAM! (Certas expressões nunca saem de moda, ok?)

# %% [markdown]
# Agora temos todas as ocorrências em Sampa, nossa grande campeã, que de mais de 44 mil linhas possui mais de 29 mil. Top!
#
# *Rindo de nervoso*

# %% [markdown]
# Tá bem... A Prefs paulistana pediu pra gente dar uma analisada no que aconteceu com esses crimes, os desdobramentos dos casos. Meio de olho a gente vê que tem muito NaN, que significa Not a Number, mas que na verdade deveria ser NtN, "Não tem, Não". Ou seja, por um algum motivo não temos esses dados. #chateads

# %% [markdown]
# Vamos lá, vamos ver o que rolou com essa parada. Vamos usar de novo o .value_counts somado ao sum(), que vai contar pra gente quantos dados de desdobramento nós temos.

# %%
data['DESDOBRAMENTO'].value_counts().sum()
# Out:
# 102

# %% [markdown]
# Eita Giovana! Liga pro 156 que a coisa tá feia! De quase 30 mil resultados só 102 tem dado de desdobramento. Podem ser várias coisas e nós não somos a mãe Diná, mas tá aí uma coisa legal pra prefs dar um jeito pra próxima vez, né? Ver se esses desdobramentos tão em curso, se o TDA tá atrapalhando o pessoal da firma...
#
# ps: Para fins culturais (https://www.youtube.com/watch?v=6COuFpVYDv8)

# %% [markdown]
# A gente é curioso, vamos ver os casos que tem desdobramento, só tirar o sum e 'mais uma vez o .value_counts salva o dia!'.
#
# ps: esse não precisa de referência que todo mundo teve infância
#
# ps2: Meninas Superpoderosas

# %%
data['DESDOBRAMENTO'].value_counts()
# Out:
# Morte decorrente de intervenÃ§Ã£o policial (RES. SSP 05 - 07/01/2013)                   34
# Meio empregado para destruiÃ§Ã£o ou rompimento de obstÃ¡culo Ã  subtraÃ§Ã£o da coisa    30
# LesÃ£o corporal decorrente de intervenÃ§Ã£o policial (RES. SSP 05 - 07/01/2013)         19
# Â§3o. Se da violÃªncia resulta lesÃ£o corporal grave:                                    9
# Â§3o. Se da violÃªncia resulta morte:                                                    8
# No homicÃ­dio culposo cometido na direÃ§Ã£o de veÃ­culo automotor                        2
# Name: DESDOBRAMENTO, dtype: int64

# %% [markdown]
# Boa sorte, prefs. Que a gente não entendeu nada.
