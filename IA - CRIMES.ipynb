# %% [markdown]
# No mês de abril nos foi solicitado fazer um levantamento de dados de crimes em São Paulo no ano de 2016 pela prefeitura, a fim de levantar dados para comparar um ano com o outro e remanejar melhor os policiais.
# Pra isso, recebemos 50 mil dados que levam em consideração o local, o tipo de crime e onde foram registrados, entre outros.

# %% [markdown]
# Pra fazer esse levantamento, importamos a biblioteca pandas, que facilita a análise desses dados.

# %%
import pandas as pd

# %% [markdown]
# Como o arquivo que recebemos é do excel em formato csv, precisamos fazer a leitura do mesmo.

# %%
data = pd.read_csv('crimes_2016.csv')

# %% [markdown]
# Pra fazer uma rápida verificação pra saber se está funcionando tudo certinho, usamos o .head(), que nos traz os primeiros elementos do arquivo.

# %%
data.head()
# Out:
#    NUM_BO  ANO_BO  ID_DELEGACIA                         NOME_DEPARTAMENTO  \
# 0   10957    2016         20249  DECAP
# 1    1672    2016         20230  DECAP
# 2     211    2016         10376  DECAP
# 3    4438    2016         10323  DECAP
# 4  676155    2016        900020  DIPOL - DEPTO DE INTELIGENCIA
#
#                              NOME_SECCIONAL                       DELEGACIA  \
# 0  DEL.SEC.8º SAO MATEUS                     49º D.P.  SAO MATEUS
# 1  DEL.SEC.5º LESTE                          30º D.P.  TATUAPE
# 2  DEL.SEC.3º OESTE                          09ª DEL.DEF.MUL. OESTE
# 3  DEL.SEC.3º OESTE                          23º D.P.  PERDIZES
# 4  DELEGACIA ELETRONICA                      DELEGACIA ELETRONICA
#
#                      NOME_DEPARTAMENTO_CIRC  \
# 0  DECAP
# 1  DECAP
# 2  DECAP
# 3  DECAP
# 4  DECAP
#
#                         NOME_SECCIONAL_CIRC             NOME_DELEGACIA_CIRC  \
# 0  DEL.SEC.8º SAO MATEUS                     49º D.P.  SAO MATEUS
# ...

# %% [markdown]
# Eba! Tá tudo certinho! Agora podemos rodar todo o arquivo e pra isso chamamos nossa variável data.

# %%
data
# Out:
#         NUM_BO  ANO_BO  ID_DELEGACIA  \
# 0        10957    2016         20249
# 1         1672    2016         20230
# 2          211    2016         10376
# 3         4438    2016         10323
# 4       676155    2016        900020
# ...        ...     ...           ...
# 49995     2063    2016         10374
# 49996  1356710    2016        900020
# 49997     1318    2016         10359
# 49998     5536    2016         10336
# 49999     1238    2016         20301
#
#                               NOME_DEPARTAMENTO  \
# 0      DECAP
# 1      DECAP
# 2      DECAP
# 3      DECAP
# 4      DIPOL - DEPTO DE INTELIGENCIA
# ...                                         ...
# 49995  DECAP
# 49996  DIPOL - DEPTO DE INTELIGENCIA
# 49997  DECAP
# 49998  DECAP
# 49999  DECAP
#
#                                  NOME_SECCIONAL  \
# 0      DEL.SEC.8º SAO MATEUS
# 1      DEL.SEC.5º LESTE
# 2      DEL.SEC.3º OESTE
# 3      DEL.SEC.3º OESTE
# 4      DELEGACIA ELETRONICA
# ...

# %% [markdown]
# A própria tabela nos mostra que são 50 mil linhas com 21 colunas, é coisa pra caramba!

# %% [markdown]
# Vamos analisar o total de ocorrências em cada cidade utilizando o .value_counts().

# %%
data['CIDADE'].value_counts()
# Out:
# S.PAULO                                     33168
# GUARULHOS                                    2255
# S.BERNARDO DO CAMPO                          1811
# S.ANDRE                                      1799
# OSASCO                                       1736
# DIADEMA                                      1120
# MAUA                                          871
# CARAPICUIBA                                   704
# MOGI DAS CRUZES                               615
# ITAQUAQUECETUBA                               557
# SUZANO                                        472
# BARUERI                                       466
# TABOAO DA SERRA                               436
# COTIA                                         397
# FERRAZ DE VASCONCELOS                         305
# ITAPECERICA DA SERRA                          295
# ITAPEVI                                       292
# EMBU                                          291
# S.CAETANO DO SUL                              275
# ...

# %% [markdown]
# Opa! Como podemos ver, temos cidade da grande São Paulo e mais do interior e litoral, mas nesse caso, nos atentaremos para a capital.

# %%
data.CIDADE == "S.PAULO"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Name: CIDADE, Length: 50000, dtype: bool

# %%
data.loc[:, "CIDADE"]
# Out:
# 0        S.PAULO
# 1        S.PAULO
# 2        S.PAULO
# 3        S.PAULO
# 4        S.PAULO
#                            ...
# 49995    S.PAULO
# 49996    S.PAULO
# 49997    S.PAULO
# 49998    S.PAULO
# 49999    S.PAULO
# Name: CIDADE, Length: 50000, dtype: object

# %%
cidade = data['CIDADE'].replace('.')

# %%
cidade = cidade.str.contains('.', regex=False)

# %%
cidade
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 49995    True
# 49996    True
# 49997    True
# 49998    True
# 49999    True
# Name: CIDADE, Length: 50000, dtype: bool
